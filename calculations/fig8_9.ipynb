# %%
import os
import sys
print(os.getcwd())
sys.path.append("../WanPy")

import numpy as np
from pythtb import *
from pythTB_wan import Bloch, K_mesh, Wannier
import models

import matplotlib.pyplot as plt
# Out:
# /Users/treycole/Codes/WanPy/top_obstruction

# %%
# tight-binding parameters
delta = 1
t = 1
t2 = -0.3

n_super_cell = 2
model = models.Haldane(delta, t, t2).make_supercell([[n_super_cell, 0], [0, n_super_cell]])

#############

low_E_sites = np.arange(0, model.get_num_orbitals(), 2)
high_E_sites = np.arange(1, model.get_num_orbitals(), 2)
lat_vecs = model.get_lat()
recip_lat_vecs = model.get_recip_lat_vecs()
orb_vecs = model.get_orb()
n_orb = model.get_num_orbitals()
n_occ = int(n_orb/2)

u_wfs_full = wf_array(model, [20, 20])
u_wfs_full.solve_on_grid([0, 0])
chern = u_wfs_full.berry_flux([i for i in range(n_occ)])/(2*np.pi)

model_str = f'C={chern:.1f}_Delta={delta}_t={t}_t2={t2}'

print(f"Low energy sites: {low_E_sites}")
print(f"High energy sites: {high_E_sites}")
print(f"Chern # occupied: {chern: .1f}")
# Out:
# Low energy sites: [0 2 4 6]
# High energy sites: [1 3 5 7]
# Chern # occupied:  1.0

# %%
### Trial wavefunctions
omit_sites = 6
tf_list = list(np.setdiff1d(low_E_sites, [omit_sites])) 
# tf_list = list(low_E_sites)

n_tfs = len(tf_list)
Wan_frac = n_tfs/n_occ

save_sfx = model_str + f'_tfx={np.array(tf_list, dtype=int)}'

print(f"Trial wavefunctions: {tf_list}")
print(f"# of Wannier functions: {n_tfs}")
print(f"# of occupied bands: {n_occ}")
print(f"Wannier fraction: {Wan_frac}")
print(save_sfx)
# Out:
# Trial wavefunctions: [np.int64(0), np.int64(2), np.int64(4)]
# # of Wannier functions: 3
# # of occupied bands: 4
# Wannier fraction: 0.75
# C=1.0_Delta=1_t=1_t2=-0.3_tfx=[0 2 4]

# %%
k_path = [[0, 0], [2/3, 1/3], [.5, .5], [1/3, 2/3], [0, 0], [.5, .5]]
k_label = (r'$\Gamma $',r'$K$', r'$M$', r'$K^\prime$', r'$\Gamma $', r'$M$')
(k_vec, k_dist, k_node) = model.k_path(k_path, 101, report=False)

model.plot_bands(
    k_path, k_label=k_label, nk=201, scat_size=2, red_lat_idx=high_E_sites, cmap='plasma'
    )
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: ylabel='Energy $E(\\mathbf{{k}})$'>)

# %%
sv_dir = 'data'
if not os.path.exists(sv_dir):
    os.makedirs(sv_dir)
    
sv_prefix = 'WF_max_loc'
file_name = f"{sv_dir}/{sv_prefix}_{save_sfx}"

WF = np.load(f"{file_name}.npy", allow_pickle=True).item()

# %%
nks = 40, 40
WF = Wannier(model, nks)

# initial projection
WF.single_shot(tf_list)
# subspace selection
iter_num = 100000
WF.subspace_selec(iter_num=iter_num, tol=1e-10, verbose=True)
# second projection
psi_til_til = WF.get_psi_tilde(
        WF.tilde_states._psi_wfs, WF.trial_wfs, 
        state_idx=list(range(WF.tilde_states._psi_wfs.shape[2]))
        )
WF.set_tilde_states(psi_til_til, cell_periodic=False)
# 196 Omega_til = 0.03461279183639382, Grad mag: 1.0639389600456618e-11
# 197 Omega_til = 0.03461279090714233, Grad mag: 1.0758813380134153e-11
# Warning: Gradient increasing.
# 198 Omega_til = 0.034612790070963434, Grad mag: 1.0605825494486466e-11
# 199 Omega_til = 0.03461278923478454, Grad mag: 1.0600995431835245e-11
# 200 Omega_til = 0.03461278839860564, Grad mag: 1.0620677114820885e-11
# Warning: Gradient increasing.
# 201 Omega_til = 0.03461278764609992, Grad mag: 1.0612855003100373e-11
# 202 Omega_til = 0.03461278689340991, Grad mag: 1.0609761836345595e-11
# 203 Omega_til = 0.03461278614090419, Grad mag: 1.0769520292355977e-11
# Warning: Gradient increasing.
# 204 Omega_til = 0.034612785463593754, Grad mag: 1.0773658696965707e-11
# Warning: Gradient increasing.
# 205 Omega_til = 0.03461278485392221, Grad mag: 1.0666377478961921e-11
# 206 Omega_til = 0.03461278424434282, Grad mag: 1.0603381241600756e-11
# 207 Omega_til = 0.034612783634763424, Grad mag: 1.0711344876361739e-11
# Warning: Gradient increasing.
# 208 Omega_til = 0.034612783086095895, Grad mag: 1.0425842634891547e-11
# 209 Omega_til = 0.03461278253733622, Grad mag: 1.0603438490857593e-11
# Warning: Gradient increasing.
# 210 Omega_til = 0.034612782043682885, Grad mag: 1.0600766651444289e-11
# 211 Omega_til = 0.03461278155002955, Grad mag: 1.0745873609168521e-11
# Warning: Gradient increasing.
# 212 Omega_til = 0.03461278110549274, Grad mag: 1.0562838296633482e-11
# 213 Omega_til = 0.034612780661232384, Grad mag: 1.0522884977489504e-11
# 214 Omega_til = 0.03461278021678773, Grad mag: 1.073184384152904e-11
# Warning: Gradient increasing.
# 215 Omega_til = 0.03461277981685204, Grad mag: 1.0498095137249263e-11
# 216 Omega_til = 0.0346127794168242, Grad mag: 1.054293135593672e-11
# Warning: Gradient increasing.
# 217 Omega_til = 0.03461277905697424, Grad mag: 1.066576884333577e-11
# Warning: Gradient increasing.
# 218 Omega_til = 0.03461277873278674, Grad mag: 1.0652149954522838e-11
# 219 Omega_til = 0.03461277840906, Grad mag: 1.0717549896661369e-11
# Warning: Gradient increasing.
# 220 Omega_til = 0.03461277811740183, Grad mag: 1.0625785694851403e-11
# 221 Omega_til = 0.03461277782592796, Grad mag: 1.0422944921590621e-11
# 222 Omega_til = 0.03461277753436195, Grad mag: 1.0632997126111347e-11
# Warning: Gradient increasing.
# 223 Omega_til = 0.03461277727182352, Grad mag: 1.0600478596734292e-11
# 224 Omega_til = 0.034612777009377246, Grad mag: 1.0702238532788469e-11
# Warning: Gradient increasing.
# 225 Omega_til = 0.03461277677328618, Grad mag: 1.0675098679146336e-11
# 226 Omega_til = 0.03461277653728727, Grad mag: 1.0619122898651145e-11
# 227 Omega_til = 0.0346127763010119, Grad mag: 1.056519104272832e-11
# 228 Omega_til = 0.03461277606482868, Grad mag: 1.0604501637258483e-11
# Warning: Gradient increasing.
# 229 Omega_til = 0.03461277585223614, Grad mag: 1.0614533020455781e-11
# Warning: Gradient increasing.
# 230 Omega_til = 0.03461277566083835, Grad mag: 1.0648953759332436e-11
# Warning: Gradient increasing.
# 231 Omega_til = 0.03461277548879228, Grad mag: 1.0478938040331719e-11
# 232 Omega_til = 0.034612775316561914, Grad mag: 1.0571918046206334e-11
# Warning: Gradient increasing.
# 233 Omega_til = 0.0346127751617481, Grad mag: 1.0645500262611026e-11
# Warning: Gradient increasing.
# 234 Omega_til = 0.034612775022323516, Grad mag: 1.0445634650720433e-11
# 235 Omega_til = 0.034612774882806785, Grad mag: 1.0709477620347795e-11
# Warning: Gradient increasing.
# 236 Omega_til = 0.03461277475729701, Grad mag: 1.055954682865555e-11
# 237 Omega_til = 0.034612774631879395, Grad mag: 1.0609008005442414e-11
# Warning: Gradient increasing.
# 238 Omega_til = 0.034612774518810015, Grad mag: 1.0693904651106497e-11
# Warning: Gradient increasing.
# 239 Omega_til = 0.03461277441707523, Grad mag: 1.0784059605539722e-11
# Warning: Gradient increasing.
# 240 Omega_til = 0.03461277432566135, Grad mag: 1.0560982247546654e-11
# 241 Omega_til = 0.03461277423415533, Grad mag: 1.0646529564594665e-11
# Warning: Gradient increasing.
# 242 Omega_til = 0.03461277415177227, Grad mag: 1.0732924441499134e-11
# Warning: Gradient increasing.
# 243 Omega_til = 0.03461277407777495, Grad mag: 1.0572714193319468e-11
# 244 Omega_til = 0.03461277400350118, Grad mag: 1.0598478027193658e-11
# Warning: Gradient increasing.
# 245 Omega_til = 0.03461277393687595, Grad mag: 1.056187486825497e-11
# 246 Omega_til = 0.03461277387015857, Grad mag: 1.0480097979743331e-11
# 247 Omega_til = 0.03461277380334903, Grad mag: 1.0553469109710266e-11
# Warning: Gradient increasing.
# 248 Omega_til = 0.03461277374335868, Grad mag: 1.0670530200300794e-11
# Warning: Gradient increasing.
# 249 Omega_til = 0.034612773689358146, Grad mag: 1.0512633403774032e-11
# 250 Omega_til = 0.03461277363535761, Grad mag: 1.0553418758610719e-11
# Warning: Gradient increasing.
# 251 Omega_til = 0.034612773586701846, Grad mag: 1.0747633008181272e-11
# Warning: Gradient increasing.
# 252 Omega_til = 0.03461277354302223, Grad mag: 1.056966455041372e-11
# 253 Omega_til = 0.03461277349934262, Grad mag: 1.0562899633824445e-11
# 254 Omega_til = 0.03461277345557086, Grad mag: 1.061638676854249e-11
# Warning: Gradient increasing.
# 255 Omega_til = 0.03461277341622235, Grad mag: 1.049174445513918e-11
# 256 Omega_til = 0.03461277337678169, Grad mag: 1.0564735202053828e-11
# Warning: Gradient increasing.
# 257 Omega_til = 0.03461277334121137, Grad mag: 1.068942059272177e-11
# Warning: Gradient increasing.
# 258 Omega_til = 0.0346127733093271, Grad mag: 1.054162399133669e-11
# 259 Omega_til = 0.034612773277442825, Grad mag: 1.0675999855134989e-11
# Warning: Gradient increasing.
# 260 Omega_til = 0.03461277324878383, Grad mag: 1.063810873556954e-11
# 261 Omega_til = 0.03461277322012485, Grad mag: 1.0675826388424868e-11
# Warning: Gradient increasing.
# 262 Omega_til = 0.034612773194230395, Grad mag: 1.0571322603298662e-11
# 263 Omega_til = 0.0346127731684281, Grad mag: 1.0624314172963539e-11
# Warning: Gradient increasing.
# 264 Omega_til = 0.03461277314520602, Grad mag: 1.0612924568504445e-11
# 265 Omega_til = 0.0346127731218918, Grad mag: 1.0539520058860953e-11
# 266 Omega_til = 0.034612773098577576, Grad mag: 1.0750764511553455e-11
# Warning: Gradient increasing.
# 267 Omega_til = 0.03461277307775143, Grad mag: 1.0496113961282474e-11
# 268 Omega_til = 0.034612773056740986, Grad mag: 1.062582436774153e-11
# Warning: Gradient increasing.
# 269 Omega_til = 0.034612773037850014, Grad mag: 1.0786953425234731e-11
# Warning: Gradient increasing.
# 270 Omega_til = 0.034612773020894216, Grad mag: 1.0508365120764294e-11
# 271 Omega_til = 0.03461277300393842, Grad mag: 1.0660053363464452e-11
# Warning: Gradient increasing.
# 272 Omega_til = 0.03461277298854919, Grad mag: 1.0603775210349699e-11
# 273 Omega_til = 0.03461277297325211, Grad mag: 1.0698682798241087e-11
# Warning: Gradient increasing.
# 274 Omega_til = 0.03461277295961375, Grad mag: 1.0581029368318618e-11
# 275 Omega_til = 0.03461277294588324, Grad mag: 1.0571911855343484e-11
# 276 Omega_til = 0.03461277293224488, Grad mag: 1.0571229537305344e-11
# 277 Omega_til = 0.034612772918698666, Grad mag: 1.0563945608120797e-11
# 278 Omega_til = 0.03461277290487601, Grad mag: 1.0611847448399256e-11
# Warning: Gradient increasing.
# 279 Omega_til = 0.03461277289252776, Grad mag: 1.0512167435632107e-11
# 280 Omega_til = 0.034612772880087364, Grad mag: 1.0602203769050375e-11
# Warning: Gradient increasing.
# 281 Omega_til = 0.03461277286902924, Grad mag: 1.0581932013612951e-11
# 282 Omega_til = 0.03461277285797111, Grad mag: 1.0598025207762353e-11
# Warning: Gradient increasing.
# 283 Omega_til = 0.03461277284783449, Grad mag: 1.0611928102422078e-11
# Warning: Gradient increasing.
# 284 Omega_til = 0.03461277283908014, Grad mag: 1.0509741062489022e-11
# 285 Omega_til = 0.03461277282986503, Grad mag: 1.0487647111186537e-11
# 286 Omega_til = 0.03461277282083422, Grad mag: 1.0598226244010836e-11
# Warning: Gradient increasing.
# 287 Omega_til = 0.03461277281281708, Grad mag: 1.0671647616123715e-11
# Warning: Gradient increasing.
# 288 Omega_til = 0.03461277280544499, Grad mag: 1.0653398541981145e-11
# 289 Omega_til = 0.034612772798165055, Grad mag: 1.0615322344989112e-11
# 290 Omega_til = 0.03461277279079297, Grad mag: 1.062311836342158e-11
# Warning: Gradient increasing.
# 291 Omega_til = 0.0346127727843424, Grad mag: 1.0570025631843045e-11
# 292 Omega_til = 0.03461277277761537, Grad mag: 1.044318742646156e-11
# 293 Omega_til = 0.03461277277116479, Grad mag: 1.062941640030166e-11
# Warning: Gradient increasing.
# 294 Omega_til = 0.03461277276526712, Grad mag: 1.065199788935829e-11
# Warning: Gradient increasing.
# 295 Omega_til = 0.03461277275992236, Grad mag: 1.0515587247289179e-11
# 296 Omega_til = 0.03461277275466975, Grad mag: 1.0533437263602289e-11
# Warning: Gradient increasing.
# 297 Omega_til = 0.034612772749970044, Grad mag: 1.0590904164221614e-11
# Warning: Gradient increasing.
# 298 Omega_til = 0.03461277274536249, Grad mag: 1.054261603326138e-11
# 299 Omega_til = 0.03461277274103139, Grad mag: 1.0629272508633615e-11
# Warning: Gradient increasing.
# 300 Omega_til = 0.034612772737253196, Grad mag: 1.043912346056174e-11
# 301 Omega_til = 0.0346127727332907, Grad mag: 1.0480459028717009e-11
# Warning: Gradient increasing.
# 302 Omega_til = 0.03461277272978896, Grad mag: 1.0480975488840902e-11
# Warning: Gradient increasing.
# 303 Omega_til = 0.03461277272665582, Grad mag: 1.0558584160549938e-11
# Warning: Gradient increasing.
# 304 Omega_til = 0.03461277272389129, Grad mag: 1.044104489115113e-11
# 305 Omega_til = 0.03461277272094245, Grad mag: 1.0597427400604917e-11
# Warning: Gradient increasing.
# 306 Omega_til = 0.03461277271854652, Grad mag: 1.0478614941265009e-11
# 307 Omega_til = 0.03461277271596629, Grad mag: 1.0548594000997568e-11
# Warning: Gradient increasing.
# 308 Omega_til = 0.03461277271366252, Grad mag: 1.0532106106755464e-11
# 309 Omega_til = 0.03461277271145089, Grad mag: 1.0416109577844398e-11
# 310 Omega_til = 0.034612772709147116, Grad mag: 1.0583666012348014e-11
# Warning: Gradient increasing.
# 311 Omega_til = 0.03461277270702764, Grad mag: 1.0550968424033788e-11
# 312 Omega_til = 0.034612772705000315, Grad mag: 1.057046116081219e-11
# Warning: Gradient increasing.
# 313 Omega_til = 0.034612772703157296, Grad mag: 1.0496851739224238e-11
# 314 Omega_til = 0.03461277270122212, Grad mag: 1.0489119978500922e-11
# 315 Omega_til = 0.03461277269947125, Grad mag: 1.0606209289379958e-11
# Warning: Gradient increasing.
# 316 Omega_til = 0.03461277269781253, Grad mag: 1.057376488284448e-11
# 317 Omega_til = 0.03461277269606166, Grad mag: 1.0560348987156633e-11
# 318 Omega_til = 0.03461277269440294, Grad mag: 1.0563582520954836e-11
# Warning: Gradient increasing.
# 319 Omega_til = 0.03461277269292853, Grad mag: 1.0550584190415975e-11
# 320 Omega_til = 0.034612772691361954, Grad mag: 1.0516926701255658e-11
# 321 Omega_til = 0.034612772689887536, Grad mag: 1.0459089167750619e-11
# 322 Omega_til = 0.03461277268841312, Grad mag: 1.0651028888559455e-11
# Warning: Gradient increasing.
# 323 Omega_til = 0.034612772687030856, Grad mag: 1.049726755159214e-11
# 324 Omega_til = 0.034612772685648587, Grad mag: 1.0606506943783243e-11
# Warning: Gradient increasing.
# 325 Omega_til = 0.03461277268435847, Grad mag: 1.0685507176307163e-11
# Warning: Gradient increasing.
# 326 Omega_til = 0.03461277268334481, Grad mag: 1.0580763073975407e-11
# 327 Omega_til = 0.034612772682239, Grad mag: 1.0489559621582191e-11
# 328 Omega_til = 0.034612772681133185, Grad mag: 1.0624481322769295e-11
# Warning: Gradient increasing.
# 329 Omega_til = 0.03461277268021167, Grad mag: 1.0560659371105956e-11
# 330 Omega_til = 0.03461277267919801, Grad mag: 1.0585751580026565e-11
# Warning: Gradient increasing.
# 331 Omega_til = 0.034612772678276504, Grad mag: 1.0547315769464368e-11
# 332 Omega_til = 0.03461277267744714, Grad mag: 1.0451778986039498e-11
# 333 Omega_til = 0.03461277267670993, Grad mag: 1.0548017644961747e-11
# Warning: Gradient increasing.
# 334 Omega_til = 0.034612772675788425, Grad mag: 1.0557102523535514e-11
# Warning: Gradient increasing.
# 335 Omega_til = 0.034612772675051216, Grad mag: 1.0419953330447237e-11
# 336 Omega_til = 0.03461277267431401, Grad mag: 1.0547978681793357e-11
# Warning: Gradient increasing.
# 337 Omega_til = 0.03461277267366895, Grad mag: 1.0593757563040971e-11
# Warning: Gradient increasing.
# 338 Omega_til = 0.03461277267293174, Grad mag: 1.0608853597449523e-11
# Warning: Gradient increasing.
# 339 Omega_til = 0.03461277267247098, Grad mag: 1.0577243166300338e-11
# 340 Omega_til = 0.03461277267210238, Grad mag: 1.0458552086242909e-11
# 341 Omega_til = 0.034612772671549476, Grad mag: 1.0583012512977688e-11
# Warning: Gradient increasing.
# 342 Omega_til = 0.034612772670996564, Grad mag: 1.0526255340149846e-11
# 343 Omega_til = 0.03461277267044366, Grad mag: 1.0457074435588505e-11
# 344 Omega_til = 0.034612772670167206, Grad mag: 1.0602341686452968e-11
# Warning: Gradient increasing.
# 345 Omega_til = 0.03461277266970645, Grad mag: 1.0421799139247401e-11
# 346 Omega_til = 0.03461277266933785, Grad mag: 1.0506510962703804e-11
# Warning: Gradient increasing.
# 347 Omega_til = 0.03461277266896924, Grad mag: 1.0548572123261076e-11
# Warning: Gradient increasing.
# 348 Omega_til = 0.034612772668508485, Grad mag: 1.0464397518184318e-11
# 349 Omega_til = 0.03461277266832419, Grad mag: 1.0521543486492597e-11
# Warning: Gradient increasing.
# 350 Omega_til = 0.03461277266786343, Grad mag: 1.0482615539503821e-11
# 351 Omega_til = 0.03461277266767913, Grad mag: 1.0515705772794626e-11
# Warning: Gradient increasing.
# 352 Omega_til = 0.034612772667310526, Grad mag: 1.0570643404699742e-11
# Warning: Gradient increasing.
# 353 Omega_til = 0.03461277266712622, Grad mag: 1.0412649463240635e-11
# 354 Omega_til = 0.03461277266684977, Grad mag: 1.0608422135655958e-11
# Warning: Gradient increasing.
# 355 Omega_til = 0.03461277266657332, Grad mag: 1.0614992900480619e-11
# Warning: Gradient increasing.
# 356 Omega_til = 0.03461277266648116, Grad mag: 1.0443924992576867e-11
# 357 Omega_til = 0.034612772666296865, Grad mag: 1.0513971328659436e-11
# Warning: Gradient increasing.
# 358 Omega_til = 0.034612772666020405, Grad mag: 1.063107120692331e-11
# Warning: Gradient increasing.
# 359 Omega_til = 0.03461277266592826, Grad mag: 1.0665245866476261e-11
# Warning: Gradient increasing.
# 360 Omega_til = 0.034612772665651804, Grad mag: 1.0532639401958394e-11
# 361 Omega_til = 0.034612772665559656, Grad mag: 1.0611527781269338e-11
# Warning: Gradient increasing.
# 362 Omega_til = 0.034612772665559656, Grad mag: 1.062764806296587e-11
# Omega_tilde minimization has converged within tolerance. Breaking the loop.

# %%
WF.report()
# Out:
# Wannier function report
#  ---------------------
# Quadratic spreads:
# w_0 --> 0.20186
# w_1 --> 0.20186
# w_2 --> 0.20186
# Centers:
# w_0 --> [0.16125 0.16125]
# w_1 --> [0.16125 0.67749]
# w_2 --> [0.67749 0.16125]
# Omega_i = 0.5706005404460939
# Omega_tilde = 0.0349731209612598

# %%
WF.plot_density(0, show_lattice=False, lat_size=2, cbar=False, return_fig=True, interpolate=False)
# plt.xlim(-20, 20)
# plt.ylim(-20, 20)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
kwargs_centers = {'marker': '*', 'c': 'dodgerblue', 'alpha': 0.6} 
kwargs_omit = {'s': 70, 'marker': 'x', 'c': 'k', 'zorder': 3} 
kwargs_lat = {'s': 15, 'marker': 'o', 'c': 'k'} 

fig, ax = WF.plot_centers(
    center_scale=50, omit_sites=[omit_sites], section_home_cell=True, 
    color_home_cell=True, translate_centers=True, kwargs_centers=kwargs_centers, 
    kwargs_lat=kwargs_lat, kwargs_omit=kwargs_omit, pmx=3, pmy=3, legend=True)

# %%
# interpolated energies and states 
interp_energies, interp_unk_til = WF.interp_energies(k_vec, ret_eigvecs=True)

# %%
nks = WF.K_mesh.nks
Nk = np.prod(nks)
N_cells = np.prod([ nk -1 for nk in nks])
A_plaq = model.get_recip_vol() / (N_cells)

# Energy eigstates on full mesh
Bloch_en = WF.energy_eigstates
u_energy = Bloch_en.get_states()["Cell periodic"]  # energy eigenstates
P, Q = Bloch_en.get_projector(return_Q=True)  # full band projector

# occupied energy eigenstates
u_occ = u_energy[..., :n_occ, :]  # occupied energy eigenstates
Bloch_occ = Bloch(model, u_occ.shape[0], u_occ.shape[1])
Bloch_occ.set_wfs(u_occ, cell_periodic=True)
P_occ, Q_occ = Bloch_occ.get_projector(return_Q=True)

# tilde states
Bloch_tilde = WF.tilde_states
u_tilde = Bloch_tilde.get_states()["Cell periodic"]  # reduced tilde states
P_tilde, Q_tilde = Bloch_tilde.get_projector(return_Q=True)  # tilde space projectors

# topological states
P_diff = P_occ - P_tilde  # complementary subspace
eigvals, eigvecs = np.linalg.eigh(P_diff)  # states spanning complement
u_comp = eigvecs[..., :, -1]  # take state with non-zero eigval
u_comp = u_comp[..., np.newaxis, :]  # single state
Bloch_comp = Bloch(model, u_comp.shape[0], u_comp.shape[1])
Bloch_comp.set_wfs(u_comp, cell_periodic=True)

# %%
# Occupied states
Berry_curv = Bloch_occ.berry_flux_plaq() / A_plaq
omega_i_k = Bloch_occ.trace_metric() #[..., np.newaxis]
omega_i = np.sum(omega_i_k) / Nk

# Reduced (trivial) states  
Berry_curv_til = Bloch_tilde.berry_flux_plaq() / A_plaq
omega_i_k_til = Bloch_tilde.trace_metric() #[..., np.newaxis]
omega_i_til = np.sum(omega_i_k_til) / Nk
omega_til_til = Bloch_tilde.omega_til()

# Complementary (topological) states 
Berry_curv_comp = Bloch_comp.berry_flux_plaq() / A_plaq
omega_i_k_comp = Bloch_comp.trace_metric() #[..., np.newaxis]
omega_i_comp = np.sum(omega_i_k_comp) / Nk
omega_til_comp = Bloch_comp.omega_til()

# %%
print(np.amax([np.amax(Berry_curv), np.amax(Berry_curv_comp), np.amax(Berry_curv_til)]))
print(np.amax([np.amax(omega_i_k), np.amax(omega_i_k_comp), np.amax(omega_i_k_til)]))
# Out:
# 1.7798568162784776
# (1.901656031541029+2.1091708305374472e-16j)

# %%
# metric inequality
print((~(abs(Berry_curv) <= omega_i_k)).nonzero())
print((~(abs(Berry_curv_til) <= omega_i_k_til)).nonzero())
print((~(abs(Berry_curv_comp) <= omega_i_k_comp)).nonzero())
# Out:
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([ 9, 10, 11, 12]), array([3, 3, 3, 3]))

# %%
print(Berry_curv_comp[10,3], omega_i_k_comp[10,3])
# Out:
# 1.14735790068864 (1.1416596686275786+3.515284717562412e-16j)

# %%
print(f"Chern occupied: {A_plaq * np.sum(Berry_curv)/(2*np.pi)}")
print(f"Chern reduced: {A_plaq * np.sum(Berry_curv_til)/(2*np.pi)}")
print(f"Chern complement: {A_plaq * np.sum(Berry_curv_comp)/(2*np.pi)}")
# Out:
# Chern occupied: 1.0
# Chern reduced: 2.231270710496731e-16
# Chern complement: 1.0

# %%
print(f"Omega_I occupied: {omega_i}")
print(f"Omega_I reduced: {omega_i_til}")
print(f"Omega_I complement: {omega_i_comp}")
print(f"Omega_tilde reduced: {omega_til_til}")
print(f"Omega_tilde comeplement: {omega_til_comp}")
# Out:
# Omega_I occupied: (0.5885816431929302+4.154695783473716e-17j)
# Omega_I reduced: (0.5706005404455177+2.5886776365424453e-17j)
# Omega_I complement: (0.6295961459682725-2.9293581593655833e-17j)
# Omega_tilde reduced: 0.0349731209612598
# Omega_tilde comeplement: 11.230698606698315

# %% [markdown]
# # Quantum Metric

# %%
k_mesh = Bloch_en.K_mesh
full_mesh = k_mesh.gen_k_mesh(endpoint=False)
full_mesh_mat = k_mesh.gen_k_mesh(flat=False, endpoint=False)
mesh_Cart = full_mesh_mat @ recip_lat_vecs

KX = mesh_Cart[:, :, 0]
KY = mesh_Cart[:, :, 1]

kx_shape = KX.shape[0]
ky_shape = KY.shape[0]

# Define the number of tiles in each direction
Nx, Ny = 3, 3  # Number of times to tile in x and y directions

# Expand KX, KY, and omega_i_k to the size of the tiled grid
KX_tiled = np.tile(KX, (Nx, Ny))  # Tile KX Nx times along x and Ny times along y
KY_tiled = np.tile(KY, (Nx, Ny))

# Apply reciprocal lattice translations to each tile
for i in range(Nx):
    for j in range(Ny):
        # Apply the appropriate translation for each tile
        KX_tiled[i *kx_shape :(i + 1) * kx_shape, j * ky_shape:(j + 1) * ky_shape] += i * recip_lat_vecs[0, 0] + j * recip_lat_vecs[1, 0]
        KY_tiled[i * kx_shape:(i + 1) * kx_shape, j * ky_shape:(j + 1) * ky_shape] += i * recip_lat_vecs[0, 1] + j * recip_lat_vecs[1, 1]

# %%
fig = plt.figure(figsize=(5, 5))
gs = fig.add_gridspec(2, 3, wspace=0.1, hspace=0.1, width_ratios=[1, 1, 1.28])
ax = gs.subplots(sharex='col', sharey='row')

###################### Berry Curve #######################

max_Bcurv = np.amax([np.amax(Berry_curv), np.amax(Berry_curv_comp), np.amax(Berry_curv_til)])
vmin, vmax = -max_Bcurv.real, max_Bcurv.real

### occupied subspace
Berry_curv_tiled = np.tile(Berry_curv, (Nx, Ny))
im = ax[0,0].pcolormesh(KX_tiled, KY_tiled, Berry_curv_tiled, cmap='seismic', shading='gouraud', vmin=vmin, vmax=vmax)
# plt.colorbar(im, label=r'$\Omega(\mathbf{k})$')

# ax[0,0].set_xlabel('$k_x$', size=12)
ax[0,0].xaxis.set_visible(False)
# ax[0,0].yaxis.set_visible(False)
ax[0,0].set_ylabel('$k_y$', size=12)
ax[0,0].set_title(r'Occupied')
# ax[0,0].set_aspect('equal')

### reduced subspace
Berry_curv_tiled = np.tile(Berry_curv_til, (Nx, Ny))

im = ax[0,2].pcolormesh(KX_tiled, KY_tiled, Berry_curv_tiled, cmap='seismic', shading='gouraud', vmin=vmin, vmax=vmax)
cb = plt.colorbar(im, fraction=0.2)
cb.set_label('$\mathcal{B}(\mathbf{k})$', size=12)

# ax[0,2].set_xlabel('$k_x$', size=12)
ax[0,2].xaxis.set_visible(False)
ax[0,2].yaxis.set_visible(False)
ax[0,2].set_title(r'Trivial')
# ax[0,2].set_aspect('equal')

### complementary subspace
# omega_i_k_tiled = np.tile(omega_i_k_comp[:, :, 0].real, (Nx, Ny))
Berry_curv_tiled = np.tile(Berry_curv_comp, (Nx, Ny))

# Plotting
im = ax[0,1].pcolormesh(KX_tiled, KY_tiled, Berry_curv_tiled, cmap='seismic', shading='gouraud', vmin=vmin, vmax=vmax)
# plt.colorbar(im, label=r'$\Omega(\mathbf{k})$', fraction=0.087)

# ax[0,1].set_xlabel('$k_x$', size=12)
ax[0,1].xaxis.set_visible(False)
ax[0,1].yaxis.set_visible(False)
ax[0,1].set_title(r'Topological')
# ax[0,1].set_aspect('equal')

################## omega_I ##########################

# vmin = 0
# vmax = np.amax([np.amax(omega_i_k), np.amax(omega_i_k_comp), np.amax(omega_i_k_til)]).real

### occupied subspace
omega_i_k_tiled = np.tile(omega_i_k.real, (Nx, Ny))
im = ax[1, 0].pcolormesh(KX_tiled, KY_tiled, omega_i_k_tiled, cmap='seismic', shading='gouraud', vmin=vmin, vmax=vmax)
# plt.colorbar(im, label=r'$\omega_I(\mathbf{k})$')

ax[1, 0].set_xlabel('$k_x$', size=12)
ax[1, 0].set_ylabel('$k_y$', size=12)
# ax[1, 0].set_title(r'Occupied')
# ax[1, 0].set_aspect('equal')

### reduced subspace
omega_i_k_tiled = np.tile(omega_i_k_til.real, (Nx, Ny))

# vmin, vmax = 0.000, np.amax(omega_i_k_comp)
# vmin, vmax = None, None
im = ax[1, 2].pcolormesh(KX_tiled, KY_tiled, omega_i_k_tiled, cmap='seismic', shading='gouraud', vmin=vmin, vmax=vmax)
cb = plt.colorbar(im, fraction=0.2)
# cb.set_ticks([0, 1])
cb.set_label('$\omega_I(\mathbf{k})$', size=12)

ax[1, 2].set_xlabel('$k_x$', size=12)
ax[1, 2].yaxis.set_visible(False)
# ax[1, 2].set_title(r'Reduced')
# ax[1, 2].set_aspect('equal')

### complementary subspace
omega_i_k_tiled = np.tile(omega_i_k_comp.real, (Nx, Ny))

# vmin, vmax = 0.000, np.amax(omega_i_k_comp)
# vmin, vmax = None, None
im = ax[1,1].pcolormesh(KX_tiled, KY_tiled, omega_i_k_tiled, cmap='seismic', shading='gouraud', vmin=vmin, vmax=vmax)
# plt.colorbar(im, label=r'$\Omega(\mathbf{k})$', fraction=0.087)

ax[1, 1].set_xlabel('$k_x$', size=12)
ax[1, 1].yaxis.set_visible(False)
# ax[1, 1].set_title(r'Complementary')
# ax[1, 1].set_aspect('equal')

# plt.subplots_adjust(wspace=-0.5)

let = np.array([['a', 'b', 'c'], ['d', 'e', 'f']])
for row in range(ax.shape[0]):
    for col in range(ax.shape[1]):
        ax[row, col].text(7, 8, f'({let[row, col]})', size=12)

plt.subplots_adjust(top=0.95, left=0.14, bottom=0.1, right=0.92)
# fig.set_constrained_layout_pads(w_pad=-0.5)
plt.savefig(f"images/berry_curv_and_omega_I_{save_sfx}.png", dpi=700)

# %%
k_path = [[0, 0], [2/3, 1/3], [.5, .5], [1/3, 2/3], [0, 0], [.5, .5]]
k_label = (r'$\Gamma $',r'$K$', r'$M$', r'$K^\prime$', r'$\Gamma $', r'$M$')
# k_path = [[0, 0], [-.5, -.5], [0,0], [.5, .5]]
# k_label = (r'$\Gamma $', r'$M$', r'$\Gamma $', r'$M$')
(k_vec, k_dist, k_node) = model.k_path(k_path, 101, report=False)

Berry_curv_comp_path = Bloch_comp.interp_op(Berry_curv_comp, k_vec, plaq=True)
Berry_curv_til_path = Bloch_tilde.interp_op(Berry_curv_til, k_vec, plaq=True)
Berry_curv_path = Bloch_occ.interp_op(Berry_curv, k_vec, plaq=True)

omega_i_k_path = Bloch_occ.interp_op(omega_i_k, k_vec)
omega_i_k_til_path = Bloch_tilde.interp_op(omega_i_k_til, k_vec)
omega_i_k_comp_path = Bloch_comp.interp_op(omega_i_k_comp, k_vec)

# %%
fig, ax = plt.subplots(2, 1, sharex=True)

ax[0].set_xlim(0, k_node[-1])
ax[0].set_xticks(k_node)
for n in range(len(k_node)):
    ax[0].axvline(x=k_node[n], linewidth=0.8, color='k')
if k_label is not None:
    ax[0].set_xticklabels(k_label, size=12)

ax[0].plot(k_dist, Berry_curv_til_path.real, c='b', label='Trivial')
ax[0].plot(k_dist, Berry_curv_comp_path.real, c='r', label='Topological')
ax[0].plot(k_dist, Berry_curv_path.real, c='g', label='Occupied')
ax[0].set_ylabel(r'$\mathcal{B}(k)$', size=12)
ax[0].legend()
ax[0].text(0.05, 1.5, '(a)', size=12)
ax[0].axhline(y=0, linewidth=0.8, color='k', zorder=0)

ax[1].set_xlim(0, k_node[-1])
ax[1].set_xticks(k_node)
for n in range(len(k_node)):
    ax[1].axvline(x=k_node[n], linewidth=0.8, color='k')
# if k_label is not None:
#     ax[1].set_xticklabels(k_label, size=12)

ax[1].plot(k_dist, omega_i_k_til_path.real, c='b', label='Trivial')
ax[1].plot(k_dist, omega_i_k_comp_path.real, c='r', label='Topological')
ax[1].plot(k_dist, omega_i_k_path.real, c='g', label='Occupied')
ax[1].set_ylabel(r'$\omega_I(k)$', size=12)
ax[1].legend()
ax[1].text(0.05, 1.5, '(b)', size=12)

plt.subplots_adjust(top=0.95, left=0.12, bottom=0.1, right=0.97, hspace=0.1)
plt.savefig(f"images/berry_curv_and_omega_I_interp_{save_sfx}.png", dpi=700)
